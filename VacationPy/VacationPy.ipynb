# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %%
#Load Data from excercise 1 into DF
cities= "../WeatherPy/output_data/Cities_raw_data.csv"
cities_df = pd.read_csv(cities)
cities_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           najran  17.4924   44.1277     93.85      40.0       100.0
# 1         takoradi   4.8845   -1.7554     77.04      82.0       100.0
# 2        poronaysk  49.2167  143.1167     61.25      96.0       100.0
# 3         koregaon  18.6500   74.0833     74.28      89.0       100.0
# 4             faya  18.3851   42.4509     68.52      49.0       100.0
# ..             ...      ...       ...       ...       ...         ...
# 603        camenca  48.0319   28.6978     77.09      59.0         0.0
# 604       kargasok  59.0556   80.8572     53.29      89.0       100.0
# 605  saint anthony  45.0205  -93.2180     83.25      44.0         1.0
# 606         awbari  26.5921   12.7805     94.26      14.0        38.0
# 607       namyslow  51.0759   17.7228     76.59      82.0         3.0
#
#      Wind Speed Country
# 0          9.40      SA
# 1          9.48      GH
# 2          3.18      RU
# 3         13.85      IN
# 4          4.76      SA
# ..          ...     ...
# 603        2.08      MD
# 604        9.60      RU
# 605        3.00      US
# 606        9.10      LY
# 607        7.31      PL
#
# [608 rows x 8 columns]

# %%
#configure gmaps and Use the Lat and Lng as locations and Humidity as the weight.Add Heatmap layer to map.
gmaps.configure(api_key=g_key)

cities_df= cities_df.dropna()
locations = cities_df[["Lat", "Lng"]].astype(float)
humidity= cities_df["Humidity"].astype(float)

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Narrow down the cities to fit weather conditions.Drop any rows will null values
Cities_Vacation_df =  cities_df.loc[(cities_df['Max Temp']>80) & (cities_df['Lat']<0) & (cities_df['Lat']>-10)]
Cities_Vacation_df
# Out:
#                          City     Lat       Lng  Max Temp  Humidity  \
# 41                  hithadhoo -0.6000   73.0833     82.18      77.0
# 42                     tutoia -2.7619  -42.2744     84.18      70.0
# 44                      buala -8.1450  159.5921     80.02      86.0
# 66                   lorengau -2.0226  147.2712     82.00      80.0
# 115                   mazagao -0.1150  -51.2894     89.65      60.0
# 225             alta floresta -9.8756  -56.0861     94.82      23.0
# 238                   kavieng -2.5744  150.7967     82.62      76.0
# 244            nisia floresta -6.0911  -35.2086     85.01      65.0
# 247  sao gabriel da cachoeira -0.1303  -67.0892     85.80      74.0
# 287                    inhuma -6.6683  -41.7078     90.52      29.0
# 306                     conde -7.2597  -34.9075     81.86      69.0
# 317                    touros -5.1989  -35.4608     85.10      65.0
# 355                   itarema -2.9248  -39.9167     83.10      68.0
# 417                     borba -4.3878  -59.5939     92.98      43.0
# 431                   lagunas -5.2269  -75.6753     90.10      49.0
# 432                   pitimbu -7.4706  -34.8086     82.99      77.0
# 459                  cururupu -1.8283  -44.8683     84.58      61.0
# 474                    kabalo -6.0500   26.9167     82.62      31.0
# 496         sao joao do piaui -8.3581  -42.2467     90.97      29.0
#
#      Cloudiness  Wind Speed Country
# 41         44.0       11.27      MV
# 42         51.0       10.67      BR
# 44         40.0        9.42      SB
# 66        100.0       10.54      PG
# 115       100.0        4.43      BR
# 225         0.0        3.44      BR
# 238       100.0       10.94      PG
# 244         7.0       13.49      BR
# 247        40.0        4.61      BR
# 287        48.0       11.27      BR
# 306        20.0       12.66      BR
# 317        52.0       16.82      BR
# 355        72.0       16.82      BR
# 417        81.0        2.01      BR
# 431        45.0        2.73      PE
# 432        10.0       13.53      BR
# 459        92.0        6.64      BR
# 474        42.0        4.63      CD
# 496        33.0       10.27      BR

# %%
Cities_Vacation_df['Hotel Name'] = ""
Cities_Vacation_df
# Out:
# C:\Users\jillp\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                          City     Lat       Lng  Max Temp  Humidity  \
# 41                  hithadhoo -0.6000   73.0833     82.18      77.0
# 42                     tutoia -2.7619  -42.2744     84.18      70.0
# 44                      buala -8.1450  159.5921     80.02      86.0
# 66                   lorengau -2.0226  147.2712     82.00      80.0
# 115                   mazagao -0.1150  -51.2894     89.65      60.0
# 225             alta floresta -9.8756  -56.0861     94.82      23.0
# 238                   kavieng -2.5744  150.7967     82.62      76.0
# 244            nisia floresta -6.0911  -35.2086     85.01      65.0
# 247  sao gabriel da cachoeira -0.1303  -67.0892     85.80      74.0
# 287                    inhuma -6.6683  -41.7078     90.52      29.0
# 306                     conde -7.2597  -34.9075     81.86      69.0
# 317                    touros -5.1989  -35.4608     85.10      65.0
# 355                   itarema -2.9248  -39.9167     83.10      68.0
# 417                     borba -4.3878  -59.5939     92.98      43.0
# 431                   lagunas -5.2269  -75.6753     90.10      49.0
# 432                   pitimbu -7.4706  -34.8086     82.99      77.0
# 459                  cururupu -1.8283  -44.8683     84.58      61.0
# 474                    kabalo -6.0500   26.9167     82.62      31.0
# 496         sao joao do piaui -8.3581  -42.2467     90.97      29.0
#
#      Cloudiness  Wind Speed Country Hotel Name
# 41         44.0       11.27      MV
# 42         51.0       10.67      BR
# 44         40.0        9.42      SB
# 66        100.0       10.54      PG
# 115       100.0        4.43      BR
# 225         0.0        3.44      BR
# 238       100.0       10.94      PG
# 244         7.0       13.49      BR
# 247        40.0        4.61      BR
# 287        48.0       11.27      BR
# 306        20.0       12.66      BR
# 317        52.0       16.82      BR
# 355        72.0       16.82      BR
# 417        81.0        2.01      BR
# 431        45.0        2.73      PE
# 432        10.0       13.53      BR
# 459        92.0        6.64      BR
# 474        42.0        4.63      CD
# 496        33.0       10.27      BR

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "radius": "5000",
    "type": "lodging",
    "key": g_key,
     
}
# use iterrows to iterate through pandas dataframe
for index, row in Cities_Vacation_df.iterrows():
    
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    city = row["City"]

    # assemble url and make API request
    print(f"Retrieving Results for {city}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        print(f"Closest hotel to {city} is {results[0]['name']}.")
        Cities_Vacation_df.loc[index, 'Hotel Name'] = results[0]['name']

        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for hithadhoo.
# Closest hotel to hithadhoo is Scoop Guest House.
# ------------
# Retrieving Results for tutoia.
# C:\Users\jillp\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest hotel to tutoia is Pousada Guará's.
# ------------
# Retrieving Results for buala.
# Closest hotel to buala is Maringe Lagoon Lodge.
# ------------
# Retrieving Results for lorengau.
# Closest hotel to lorengau is Lorengau Harbourside Hotel.
# ------------
# Retrieving Results for mazagao.
# Closest hotel to mazagao is Recanto dos Ferreiras.
# ------------
# Retrieving Results for alta floresta.
# Closest hotel to alta floresta is Floresta Amazonica Hotel.
# ------------
# Retrieving Results for kavieng.
# Closest hotel to kavieng is Nusa Island Retreat.
# ------------
# Retrieving Results for nisia floresta.
# Closest hotel to nisia floresta is Rancho Crepusculo.
# ------------
# Retrieving Results for sao gabriel da cachoeira.
# Closest hotel to sao gabriel da cachoeira is Alarne - Área De Lazer Do Alto Rio Negro.
# ------------
# Retrieving Results for inhuma.
# Closest hotel to inhuma is Edifício Bezerra.
# ------------
# Retrieving Results for conde.
# Closest hotel to conde is Pousada Beija Flor.
# ------------
# Retrieving Results for touros.
# Closest hotel to touros is INN NEW HORIZON.
# ------------
# Retrieving Results for itarema.
# Closest hotel to itarema is Sea Lounge! Bar, Club & Restaurant.
# ------------
# Retrieving Results for borba.
# Closest hotel to borba is Hotel da Amazônia.
# ------------
# Retrieving Results for lagunas.
# Closest hotel to lagunas is Hospedaje Eco.
# ------------
# Retrieving Results for pitimbu.
# Closest hotel to pitimbu is Reserva do Abiaí.
# ------------
# Retrieving Results for cururupu.
# Closest hotel to cururupu is POUSADA TRAVÉS'CIA.
# ------------
# Retrieving Results for kabalo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for sao joao do piaui.
# Closest hotel to sao joao do piaui is Nayra Palace Hotel.
# ------------

# %%
Cities_Vacation_df
# Out:
#                          City     Lat       Lng  Max Temp  Humidity  \
# 41                  hithadhoo -0.6000   73.0833     82.18      77.0
# 42                     tutoia -2.7619  -42.2744     84.18      70.0
# 44                      buala -8.1450  159.5921     80.02      86.0
# 66                   lorengau -2.0226  147.2712     82.00      80.0
# 115                   mazagao -0.1150  -51.2894     89.65      60.0
# 225             alta floresta -9.8756  -56.0861     94.82      23.0
# 238                   kavieng -2.5744  150.7967     82.62      76.0
# 244            nisia floresta -6.0911  -35.2086     85.01      65.0
# 247  sao gabriel da cachoeira -0.1303  -67.0892     85.80      74.0
# 287                    inhuma -6.6683  -41.7078     90.52      29.0
# 306                     conde -7.2597  -34.9075     81.86      69.0
# 317                    touros -5.1989  -35.4608     85.10      65.0
# 355                   itarema -2.9248  -39.9167     83.10      68.0
# 417                     borba -4.3878  -59.5939     92.98      43.0
# 431                   lagunas -5.2269  -75.6753     90.10      49.0
# 432                   pitimbu -7.4706  -34.8086     82.99      77.0
# 459                  cururupu -1.8283  -44.8683     84.58      61.0
# 474                    kabalo -6.0500   26.9167     82.62      31.0
# 496         sao joao do piaui -8.3581  -42.2467     90.97      29.0
#
#      Cloudiness  Wind Speed Country                                Hotel Name
# 41         44.0       11.27      MV                         Scoop Guest House
# 42         51.0       10.67      BR                           Pousada Guará's
# 44         40.0        9.42      SB                      Maringe Lagoon Lodge
# 66        100.0       10.54      PG                Lorengau Harbourside Hotel
# 115       100.0        4.43      BR                     Recanto dos Ferreiras
# 225         0.0        3.44      BR                  Floresta Amazonica Hotel
# 238       100.0       10.94      PG                       Nusa Island Retreat
# 244         7.0       13.49      BR                         Rancho Crepusculo
# 247        40.0        4.61      BR  Alarne - Área De Lazer Do Alto Rio Negro
# 287        48.0       11.27      BR                          Edifício Bezerra
# 306        20.0       12.66      BR                        Pousada Beija Flor
# 317        52.0       16.82      BR                           INN NEW HORIZON
# 355        72.0       16.82      BR        Sea Lounge! Bar, Club & Restaurant
# 417        81.0        2.01      BR                         Hotel da Amazônia
# 431        45.0        2.73      PE                             Hospedaje Eco
# 432        10.0       13.53      BR                          Reserva do Abiaí
# 459        92.0        6.64      BR                        POUSADA TRAVÉS'CIA
# 474        42.0        4.63      CD
# 496        33.0       10.27      BR                        Nayra Palace Hotel

# %%
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in Cities_Vacation_df.iterrows()]
locations = Cities_Vacation_df[["Lat", "Lng"]]

# %%
hotel_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=2,
    info_box_content=hotel_info
)


fig = gmaps.figure()

fig.add_layer(heat_layer)
fig.add_layer(hotel_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
